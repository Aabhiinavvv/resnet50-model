# %% [markdown]
# <a href="https://colab.research.google.com/github/Aabhiinavvv/resnet50-model/blob/main/resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input ,decode_predictions
import numpy as np

# %%
model = ResNet50(weights = 'imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#prediction for bread

# %%
img_path = ('/content/bread.jpg')
img = image.load_img(img_path,target_size=(224,224))
x = image.img_to_array(img)
x=np.expand_dims(x,axis = 0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('predicted:',decode_predictions(preds , top = 3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# predicted: [('n07684084', 'French_loaf', np.float32(0.9970253)), ('n04442312', 'toaster', np.float32(0.0015634103)), ('n02776631', 'bakery', np.float32(0.0005357137))]

# %%
#prediction for dog

# %%
img_path = ('/content/dog.jpg')
img = image.load_img(img_path,target_size=(224,224))
x = image.img_to_array(img)
x=np.expand_dims(x,axis = 0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('predicted:',decode_predictions(preds , top = 3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# predicted: [('n02099601', 'golden_retriever', np.float32(0.9774604)), ('n02099712', 'Labrador_retriever', np.float32(0.00800464)), ('n02091635', 'otterhound', np.float32(0.0036773318))]

# %%
# prediction for cat

# %%
img_path = ('/content/cat.jpg')
img = image.load_img(img_path,target_size=(224,224))
x = image.img_to_array(img)
x=np.expand_dims(x,axis = 0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('predicted:',decode_predictions(preds , top = 3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# predicted: [('n02123045', 'tabby', np.float32(0.73346436)), ('n02123159', 'tiger_cat', np.float32(0.17770484)), ('n02127052', 'lynx', np.float32(0.039576888))]
